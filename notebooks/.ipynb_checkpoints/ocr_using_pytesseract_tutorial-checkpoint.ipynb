# %%
import cv2
import matplotlib.pyplot as plt

# %%
IMAGE_PATH = './../single-info.png'

# %%
image = cv2.imread(IMAGE_PATH)

# %%
# Load an OpenCV image

# Check if the image was loaded successfully
if image is not None:
    # Convert BGR to RGB format
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Display the image using matplotlib
    plt.imshow(image_rgb)
    plt.axis('off')  # Turn off axis labels and ticks
    plt.show()
else:
    print("Failed to load the image.")

# %% [markdown]
# ## Grayscale Conversion

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## Image Binarization to convert it to black and white

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\anuj9\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (0.3.10)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\anuj9\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from pytesseract) (10.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\anuj9\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from pytesseract) (23.2)
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
_, binarized_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# %%
cv2.imwrite('processed_image.jpg', binarized_image)
# Out:
# True

# %%
# Display the binarized image using matplotlib
plt.imshow(binarized_image, cmap='gray')  # Use cmap='gray' for grayscale images
plt.axis('off')  # Turn off axis labels and ticks
plt.show()

# %%
import pytesseract 
from pytesseract import image_to_string

# %%
extracted_text = image_to_string(binarized_image)

# %%
from pytesseract import image_to_string
extracted_text = image_to_string(binarized_image)

# %%
type(extracted_text)
# Out:
# str

# %% [markdown]
# ### Verify what has been Extracted

# %%
with open('output.txt', 'w') as file:
    file.write(extracted_text)

# %% [markdown]
# ### Setup Excel

# %%
from openpyxl import Workbook

# %%
wb = Workbook()
ws = wb.active

# %%
rows = extracted_text.strip().split('\n')

# %%
rows
# Out:
# ['Date collected|Plot__|Species |Sex Weight',
#  '1/9/78 1|DM M 40',
#  '1/9/78 1|DM EF 36',
#  '1/9/78 41|DS EF 135',
#  '1/20/78 1|DM F 39',
#  '1/20/78 2|DM M 43',
#  '1/20/78 2|DS EF 144',
#  '3/13/78 2|DM EF 51',
#  '3/13/78 2|DM EF 44',
#  '3/13/78 2|DS EF 146']

# %%
for r_index, row in enumerate(rows, start=1):
    columns = row.split('\t')
    for c_index, cell_value in enumerate(columns, start=1):
        ws.cell(row=r_index, column=c_index, value=cell_value.strip())

# %%
columns
# Out:
# ['3/13/78 2|DS EF 146']

# %%
wb.save('output.xlsx')
